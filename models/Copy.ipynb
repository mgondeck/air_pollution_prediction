# %% [markdown]
# **EDA**

# %% [markdown]
# Here we clean the data:
#
# 1. remove unnecessary columns
# 2. change data types
# 3. fill missing values
# 4. round data

# %%
#import packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, RandomizedSearchCV
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import mean_squared_error, r2_score, make_scorer
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import RobustScaler
from sklearn.ensemble import RandomForestRegressor
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.feature_selection import SelectKBest, f_classif, f_regression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import StackingRegressor
from sklearn.linear_model import RidgeCV
from sklearn.svm import LinearSVR
import sys
# !{sys.executable} -m pip install xgboost
# Out:
# Requirement already satisfied: xgboost in /Users/shashankkumar/.pyenv/versions/3.11.3/lib/python3.11/site-packages (2.0.3)
# Requirement already satisfied: numpy in /Users/shashankkumar/.pyenv/versions/3.11.3/lib/python3.11/site-packages (from xgboost) (1.24.3)
# Requirement already satisfied: scipy in /Users/shashankkumar/.pyenv/versions/3.11.3/lib/python3.11/site-packages (from xgboost) (1.11.4)

# %%
from xgboost import XGBRegressor

# %%
# read in the data
df = pd.read_csv("../data/Train.csv", sep = ',')

# %% [markdown]
# **Delete unwanted columns**

# %%
df.isna().sum()
# Out:
# Place_ID X Date                     0
# Date                                0
# Place_ID                            0
# target                              0
# target_min                          0
#                                 ...
# L3_CH4_aerosol_optical_depth    24765
# L3_CH4_sensor_azimuth_angle     24765
# L3_CH4_sensor_zenith_angle      24765
# L3_CH4_solar_azimuth_angle      24765
# L3_CH4_solar_zenith_angle       24765
# Length: 82, dtype: int64

# %%
columns_to_delete = ['Place_ID X Date',
                     'Place_ID',
                     'Date',
                     'target_min', 
                     'target_max',
                     'target_variance', 
                     'target_count', 
                     #removing columns with 80% missing values
                     'L3_CH4_sensor_azimuth_angle', 
                     'L3_CH4_sensor_zenith_angle',
                     'L3_CH4_solar_azimuth_angle', 
                     'L3_CH4_solar_zenith_angle',
                     'L3_CH4_aerosol_optical_depth',
                     'L3_CH4_CH4_column_volume_mixing_ratio_dry_air',
                     'L3_CH4_aerosol_height'
                    ]

df_reduced = df.drop(columns = columns_to_delete, axis = 1)

# %% [markdown]
# **Split data into train and test sets 80/20 split**

# %%
RSEED = 9 

# Define x/y
X = df_reduced 
y = np.array(X.pop('target'))

# split train/test data
train_X, test_X, train_y, test_y = train_test_split(X, y,
                                                    test_size = 0.2, 
                                                    random_state = RSEED)

# %% [markdown]
# **Check for remaining columns, data types and null values**

# %%
train_X.isna().sum()
# Out:
# precipitable_water_entire_atmosphere       0
# relative_humidity_2m_above_ground          0
# specific_humidity_2m_above_ground          0
# temperature_2m_above_ground                0
# u_component_of_wind_10m_above_ground       0
#                                         ...
# L3_SO2_cloud_fraction                   5764
# L3_SO2_sensor_azimuth_angle             5764
# L3_SO2_sensor_zenith_angle              5764
# L3_SO2_solar_azimuth_angle              5764
# L3_SO2_solar_zenith_angle               5764
# Length: 67, dtype: int64

# %%
df_reduced.corr()
# Out:
#                                       precipitable_water_entire_atmosphere
# precipitable_water_entire_atmosphere                              1.000000  \
# relative_humidity_2m_above_ground                                 0.197203
# specific_humidity_2m_above_ground                                 0.882341
# temperature_2m_above_ground                                       0.733225
# u_component_of_wind_10m_above_ground                             -0.195106
# ...                                                                    ...
# L3_SO2_cloud_fraction                                             0.035312
# L3_SO2_sensor_azimuth_angle                                      -0.000132
# L3_SO2_sensor_zenith_angle                                        0.067864
# L3_SO2_solar_azimuth_angle                                        0.032651
# L3_SO2_solar_zenith_angle                                        -0.529087
#
#                                       relative_humidity_2m_above_ground
# precipitable_water_entire_atmosphere                           0.197203  \
# relative_humidity_2m_above_ground                              1.000000
# specific_humidity_2m_above_ground                              0.219509
# temperature_2m_above_ground                                   -0.260632
# u_component_of_wind_10m_above_ground                           0.011186
# ...                                                                 ...
# L3_SO2_cloud_fraction                                          0.324243
# L3_SO2_sensor_azimuth_angle                                   -0.007036
# L3_SO2_sensor_zenith_angle                                    -0.020469
# L3_SO2_solar_azimuth_angle                                     0.049687
# L3_SO2_solar_zenith_angle                                      0.236697
#
#                                       specific_humidity_2m_above_ground
# precipitable_water_entire_atmosphere                           0.882341  \
# relative_humidity_2m_above_ground                              0.219509
# specific_humidity_2m_above_ground                              1.000000
# temperature_2m_above_ground                                    0.816273
# u_component_of_wind_10m_above_ground                          -0.191998
# ...                                                                 ...
# L3_SO2_cloud_fraction                                         -0.055165
# L3_SO2_sensor_azimuth_angle                                    0.001297
# L3_SO2_sensor_zenith_angle                                     0.076148
# L3_SO2_solar_azimuth_angle                                     0.020177
# L3_SO2_solar_zenith_angle                                     -0.595630
#
#                                       temperature_2m_above_ground
# precipitable_water_entire_atmosphere                     0.733225  \
# relative_humidity_2m_above_ground                       -0.260632
# specific_humidity_2m_above_ground                        0.816273
# temperature_2m_above_ground                              1.000000
# u_component_of_wind_10m_above_ground                    -0.143676
# ...                                                           ...
# L3_SO2_cloud_fraction                                   -0.218556
# L3_SO2_sensor_azimuth_angle                              0.003631
# L3_SO2_sensor_zenith_angle                               0.073909
# L3_SO2_solar_azimuth_angle                               0.007059
# L3_SO2_solar_zenith_angle                               -0.666284
#
#                                       u_component_of_wind_10m_above_ground
# precipitable_water_entire_atmosphere                             -0.195106  \
# relative_humidity_2m_above_ground                                 0.011186
# specific_humidity_2m_above_ground                                -0.191998
# temperature_2m_above_ground                                      -0.143676
# u_component_of_wind_10m_above_ground                              1.000000
# ...                                                                    ...
# L3_SO2_cloud_fraction                                             0.070769
# L3_SO2_sensor_azimuth_angle                                      -0.007992
# L3_SO2_sensor_zenith_angle                                       -0.008450
# L3_SO2_solar_azimuth_angle                                        0.087557
# L3_SO2_solar_zenith_angle                                         0.229289
#
#                                       v_component_of_wind_10m_above_ground
# precipitable_water_entire_atmosphere                              0.032502  \
# relative_humidity_2m_above_ground                                 0.118368
# specific_humidity_2m_above_ground                                 0.023091
# temperature_2m_above_ground                                      -0.010511
# u_component_of_wind_10m_above_ground                              0.145513
# ...                                                                    ...
# L3_SO2_cloud_fraction                                             0.099912
# L3_SO2_sensor_azimuth_angle                                       0.001337
# L3_SO2_sensor_zenith_angle                                       -0.027155
# L3_SO2_solar_azimuth_angle                                        0.098119
# L3_SO2_solar_zenith_angle                                         0.081184
#
#                                       L3_NO2_NO2_column_number_density
# precipitable_water_entire_atmosphere                         -0.145308  \
# relative_humidity_2m_above_ground                            -0.134249
# specific_humidity_2m_above_ground                            -0.181148
# temperature_2m_above_ground                                  -0.153220
# u_component_of_wind_10m_above_ground                         -0.043865
# ...                                                                ...
# L3_SO2_cloud_fraction                                         0.021875
# L3_SO2_sensor_azimuth_angle                                   0.003261
# L3_SO2_sensor_zenith_angle                                   -0.003311
# L3_SO2_solar_azimuth_angle                                   -0.113574
# L3_SO2_solar_zenith_angle                                     0.163589
#
#                                       L3_NO2_NO2_slant_column_number_density
# precipitable_water_entire_atmosphere                               -0.239584  \
# relative_humidity_2m_above_ground                                  -0.118823
# specific_humidity_2m_above_ground                                  -0.247529
# temperature_2m_above_ground                                        -0.238809
# u_component_of_wind_10m_above_ground                                0.001337
# ...                                                                      ...
# L3_SO2_cloud_fraction                                              -0.008401
# L3_SO2_sensor_azimuth_angle                                        -0.000554
# L3_SO2_sensor_zenith_angle                                          0.118238
# L3_SO2_solar_azimuth_angle                                         -0.091441
# L3_SO2_solar_zenith_angle                                           0.254167
#
#                                       L3_NO2_absorbing_aerosol_index
# precipitable_water_entire_atmosphere                        0.037743  \
# relative_humidity_2m_above_ground                          -0.055780
# specific_humidity_2m_above_ground                          -0.012826
# temperature_2m_above_ground                                 0.031876
# u_component_of_wind_10m_above_ground                       -0.019238
# ...                                                              ...
# L3_SO2_cloud_fraction                                       0.045455
# L3_SO2_sensor_azimuth_angle                                -0.195558
# L3_SO2_sensor_zenith_angle                                  0.215107
# L3_SO2_solar_azimuth_angle                                  0.211621
# L3_SO2_solar_zenith_angle                                  -0.134379
#
#                                       L3_NO2_cloud_fraction  ...
# precipitable_water_entire_atmosphere               0.109698  ...  \
# relative_humidity_2m_above_ground                  0.324565  ...
# specific_humidity_2m_above_ground                 -0.003219  ...
# temperature_2m_above_ground                       -0.127252  ...
# u_component_of_wind_10m_above_ground               0.043174  ...
# ...                                                     ...  ...
# L3_SO2_cloud_fraction                              0.743887  ...
# L3_SO2_sensor_azimuth_angle                       -0.054617  ...
# L3_SO2_sensor_zenith_angle                         0.086447  ...
# L3_SO2_solar_azimuth_angle                         0.014935  ...
# L3_SO2_solar_zenith_angle                          0.239443  ...
#
#                                       L3_AER_AI_solar_zenith_angle
# precipitable_water_entire_atmosphere                     -0.541639  \
# relative_humidity_2m_above_ground                         0.285365
# specific_humidity_2m_above_ground                        -0.627122
# temperature_2m_above_ground                              -0.695437
# u_component_of_wind_10m_above_ground                      0.267196
# ...                                                            ...
# L3_SO2_cloud_fraction                                     0.291531
# L3_SO2_sensor_azimuth_angle                              -0.117427
# L3_SO2_sensor_zenith_angle                               -0.054384
# L3_SO2_solar_azimuth_angle                                0.013186
# L3_SO2_solar_zenith_angle                                 0.949894
#
#                                       L3_SO2_SO2_column_number_density
# precipitable_water_entire_atmosphere                         -0.067858  \
# relative_humidity_2m_above_ground                             0.000194
# specific_humidity_2m_above_ground                            -0.071769
# temperature_2m_above_ground                                  -0.078338
# u_component_of_wind_10m_above_ground                          0.006622
# ...                                                                ...
# L3_SO2_cloud_fraction                                        -0.011579
# L3_SO2_sensor_azimuth_angle                                   0.004633
# L3_SO2_sensor_zenith_angle                                   -0.008082
# L3_SO2_solar_azimuth_angle                                   -0.002805
# L3_SO2_solar_zenith_angle                                     0.068505
#
#                                       L3_SO2_SO2_column_number_density_amf
# precipitable_water_entire_atmosphere                              0.330204  \
# relative_humidity_2m_above_ground                                 0.123957
# specific_humidity_2m_above_ground                                 0.386680
# temperature_2m_above_ground                                       0.244634
# u_component_of_wind_10m_above_ground                             -0.123269
# ...                                                                    ...
# L3_SO2_cloud_fraction                                             0.141619
# L3_SO2_sensor_azimuth_angle                                       0.001911
# L3_SO2_sensor_zenith_angle                                       -0.009829
# L3_SO2_solar_azimuth_angle                                       -0.112144
# L3_SO2_solar_zenith_angle                                        -0.328149
#
#                                       L3_SO2_SO2_slant_column_number_density
# precipitable_water_entire_atmosphere                               -0.104745  \
# relative_humidity_2m_above_ground                                  -0.013460
# specific_humidity_2m_above_ground                                  -0.101513
# temperature_2m_above_ground                                        -0.106900
# u_component_of_wind_10m_above_ground                                0.000426
# ...                                                                      ...
# L3_SO2_cloud_fraction                                              -0.026270
# L3_SO2_sensor_azimuth_angle                                         0.011893
# L3_SO2_sensor_zenith_angle                                         -0.012371
# L3_SO2_solar_azimuth_angle                                         -0.006649
# L3_SO2_solar_zenith_angle                                           0.068833
#
#                                       L3_SO2_absorbing_aerosol_index
# precipitable_water_entire_atmosphere                        0.006507  \
# relative_humidity_2m_above_ground                          -0.167396
# specific_humidity_2m_above_ground                          -0.003531
# temperature_2m_above_ground                                 0.082904
# u_component_of_wind_10m_above_ground                       -0.009792
# ...                                                              ...
# L3_SO2_cloud_fraction                                      -0.105591
# L3_SO2_sensor_azimuth_angle                                -0.184242
# L3_SO2_sensor_zenith_angle                                  0.370667
# L3_SO2_solar_azimuth_angle                                  0.246763
# L3_SO2_solar_zenith_angle                                  -0.128471
#
#                                       L3_SO2_cloud_fraction
# precipitable_water_entire_atmosphere               0.035312  \
# relative_humidity_2m_above_ground                  0.324243
# specific_humidity_2m_above_ground                 -0.055165
# temperature_2m_above_ground                       -0.218556
# u_component_of_wind_10m_above_ground               0.070769
# ...                                                     ...
# L3_SO2_cloud_fraction                              1.000000
# L3_SO2_sensor_azimuth_angle                       -0.098965
# L3_SO2_sensor_zenith_angle                         0.204818
# L3_SO2_solar_azimuth_angle                         0.040373
# L3_SO2_solar_zenith_angle                          0.324347
#
#                                       L3_SO2_sensor_azimuth_angle
# precipitable_water_entire_atmosphere                    -0.000132  \
# relative_humidity_2m_above_ground                       -0.007036
# specific_humidity_2m_above_ground                        0.001297
# temperature_2m_above_ground                              0.003631
# u_component_of_wind_10m_above_ground                    -0.007992
# ...                                                           ...
# L3_SO2_cloud_fraction                                   -0.098965
# L3_SO2_sensor_azimuth_angle                              1.000000
# L3_SO2_sensor_zenith_angle                              -0.020885
# L3_SO2_solar_azimuth_angle                               0.014651
# L3_SO2_solar_zenith_angle                               -0.129849
#
#                                       L3_SO2_sensor_zenith_angle
# precipitable_water_entire_atmosphere                    0.067864  \
# relative_humidity_2m_above_ground                      -0.020469
# specific_humidity_2m_above_ground                       0.076148
# temperature_2m_above_ground                             0.073909
# u_component_of_wind_10m_above_ground                   -0.008450
# ...                                                          ...
# L3_SO2_cloud_fraction                                   0.204818
# L3_SO2_sensor_azimuth_angle                            -0.020885
# L3_SO2_sensor_zenith_angle                              1.000000
# L3_SO2_solar_azimuth_angle                              0.230882
# L3_SO2_solar_zenith_angle                               0.021546
#
#                                       L3_SO2_solar_azimuth_angle
# precipitable_water_entire_atmosphere                    0.032651  \
# relative_humidity_2m_above_ground                       0.049687
# specific_humidity_2m_above_ground                       0.020177
# temperature_2m_above_ground                             0.007059
# u_component_of_wind_10m_above_ground                    0.087557
# ...                                                          ...
# L3_SO2_cloud_fraction                                   0.040373
# L3_SO2_sensor_azimuth_angle                             0.014651
# L3_SO2_sensor_zenith_angle                              0.230882
# L3_SO2_solar_azimuth_angle                              1.000000
# L3_SO2_solar_zenith_angle                              -0.056467
#
#                                       L3_SO2_solar_zenith_angle
# precipitable_water_entire_atmosphere                  -0.529087
# relative_humidity_2m_above_ground                      0.236697
# specific_humidity_2m_above_ground                     -0.595630
# temperature_2m_above_ground                           -0.666284
# u_component_of_wind_10m_above_ground                   0.229289
# ...                                                         ...
# L3_SO2_cloud_fraction                                  0.324347
# L3_SO2_sensor_azimuth_angle                           -0.129849
# L3_SO2_sensor_zenith_angle                             0.021546
# L3_SO2_solar_azimuth_angle                            -0.056467
# L3_SO2_solar_zenith_angle                              1.000000
#
# [67 rows x 67 columns]

# %% [markdown]
# **Interpolation class**

# %%
# Custom transformer for interpolation
class InterpolateTransformer(BaseEstimator, TransformerMixin):
    def __init__(self, method='linear', limit_direction='both'):
        self.method = method
        self.limit_direction = limit_direction

    def fit(self, X, y=None):
        return self

    def transform(self, X):
        return X.interpolate(method=self.method, limit_direction=self.limit_direction)

# %%
**Feature engineering pipeline**
1. Impute all missing values from all columns
2. Log transform all columns
3.
